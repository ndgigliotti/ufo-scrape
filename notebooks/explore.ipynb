# %%
import pandas as pd

# %%
df = pd.read_json("../resources/nuforc/2023-03-20T07-03-34.json", lines=True)
df
# Out:
#                  date_time           city  state               country  \
# 0      2013-09-30 22:30:00   Glen Gardner     NJ                   USA
# 1      2013-10-31 22:15:00  Erode (India)   None                 India
# 2      2003-08-31 23:30:00         Mulino     OR                   USA
# 3      2003-09-30 22:34:00   Poplar Grove     IL                   USA
# 4      2003-10-31 23:00:00         Tucson     AZ                   USA
# ...                    ...            ...    ...                   ...
# 139760 2022-06-01 03:36:00         Dayton     MN                   USA
# 139761 2022-06-01 03:00:00        Shohola     PA                   USA
# 139762 2022-06-01 01:19:00          Dubai  Dubai  United Arab Emirates
# 139763 2022-06-01 00:01:00           Kyiv   None               Ukraine
# 139764 2022-06-01 00:00:00           Kyiv   None               Ukraine
#
#             shape                   duration  \
# 0         Unknown                 20 minutes
# ...

# %%
date_cols = ["date_time", "posted"]
df[date_cols] = df[date_cols].apply(pd.to_datetime)
df.sort_values("date_time", inplace=True)
df[date_cols]
# Out:
#                 date_time     posted
# 20891 1973-01-01 23:30:00 1999-12-16
# 20890 1973-01-02 23:00:00 2009-05-12
# 20889 1973-01-08 21:00:00 2006-03-11
# 20888 1973-01-10 02:30:00 1998-11-19
# 20887 1973-01-12 03:00:00 2002-11-20
# ...                   ...        ...
# 20882 2072-12-01 20:00:00 2003-07-16
# 20881 2072-12-06 00:00:00 2005-09-15
# 20880 2072-12-12 15:00:00 2007-02-24
# 20879 2072-12-16 22:30:00 2005-09-02
# 20878 2072-12-24 02:00:00 2011-12-12
#
# [139765 rows x 2 columns]

# %%
df.loc[df.images == "Yes"]
# Out:
#                 date_time                           city state country  \
# 21500 1975-09-01 21:30:00                         Dallas    TX     USA
# 22131 1978-05-19 21:25:00                         Tiller    OR     USA
# 22274 1978-12-18 18:00:00                    Albuquerque    NM     USA
# 22551 1980-01-03 16:50:00                    Los Angeles    CA     USA
# 23560 1984-11-08 20:00:00                       Brewster    NY     USA
# ...                   ...                            ...   ...     ...
# 18595 2057-09-05 19:15:00                      Nashville    KS     USA
# 19152 2064-06-21 20:00:00  South Ozone Park, Queens, NYC    NY     USA
# 19826 2068-02-28 18:15:00                McKenzie Bridge    OR     USA
# 20318 2069-07-01 11:00:00                        Redding    CA     USA
# 20423 2070-03-07 09:00:00                    Bonney lake    WA     USA
#
#          shape                  duration  \
# 21500     Disk                 5 minutes
# ...
